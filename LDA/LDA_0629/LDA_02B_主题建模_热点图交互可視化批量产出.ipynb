# %% [markdown]
# # 可视化
# * seaborn可视化
#    * 热点图png
#    * 热点图svg
# * plotly交互可视化 htm
#    * 热点图
#    * 柱状图

# %% [markdown]
# ## 输入/输出
#
# * 输入模型
# * 输出可视化，可用於
#     * N之决定
#     * 字词检查
#
# ## 学习目标
#
# * 观察输入输出
# * 注意数据流

# %% [markdown]
# # 输入模型

# %%
import LDA_pkl as LDAp

# %%
# 输入模型
# doc-topic Matrix 
LDAp.load_doc_topic_dists(7)
# Out:
#            1         2         3         4         5         6         7
# 1   0.000256  0.000255  0.998470  0.000255  0.000255  0.000255  0.000254
# 2   0.000314  0.000315  0.000315  0.000314  0.000314  0.998113  0.000314
# 3   0.000703  0.995785  0.000703  0.000703  0.000702  0.000703  0.000700
# 4   0.677286  0.000748  0.318997  0.000741  0.000743  0.000744  0.000740
# 5   0.995092  0.000818  0.000821  0.000819  0.000817  0.000818  0.000816
# 6   0.000543  0.000543  0.000543  0.996746  0.000542  0.000542  0.000541
# 7   0.996069  0.000658  0.000654  0.000656  0.000653  0.000658  0.000652
# 8   0.224133  0.421322  0.247497  0.068156  0.037453  0.000721  0.000718
# 9   0.713368  0.001224  0.280514  0.001225  0.001223  0.001225  0.001221
# 10  0.997297  0.000451  0.000451  0.000450  0.000451  0.000450  0.000449
# 11  0.960803  0.037485  0.000343  0.000343  0.000342  0.000342  0.000342
# 12  0.518089  0.000497  0.000498  0.368175  0.111748  0.000497  0.000496
# ...

# %% [markdown]
# # 可视化

# %%
import LDA_visualize as LDAv

# %%
# doc-topic Matrix 
dtM = LDAp.load_doc_topic_dists(7)

# 執行仿區塊建模，阈值设置 0 到 1 
#dtM = LDAv.sort_bythreshold_w_topic(dtM, 0.33, topic_label=topic_label)
dtM = LDAv.easy_block(dtM, 0.5)

# %% [markdown]
# ### 实践问题0
# * dtM的 index 是什麽?
# * dtM的 columns 是什麽?
# * dtM的 值是什麽?
# * 这和主题模型有什麽关系

# %% [markdown]
# ### 实践答案0
# 你会markdown

# %% [markdown]
# ## seaborn可视化
#    * 热点图png
#    * 热点图svg

# %%
# 试一个
LDAv.visualize_seaborn(dtM)

# %%
# 流水化?
N=7

suffix = "_{N}_全".format(N=N)
data = LDAp.load_doc_topic_dists(N)
LDAv.visualize_seaborn(data, suffix=suffix)

# %% [markdown]
# ### 实践问题1
# * 观察suffix的作用是什麽?
# * 如何影响输出结果，分图片及档案检查

# %% [markdown]
# ### 实践答案1
# 你会markdown

# %% [markdown]
# ### 实践问题2
# * 若要批量出所有建模(N值不同)如何实践

# %% [markdown]
# ### 实践答案2
# 你会markdown

# %% [markdown]
# ## plotly交互可视化
# * 热点图
# * 柱状图
#
# ### 热点图

# %%
# 试一个 热点图
# 提示 visualize_plotly_heatmap 比照上面看封装好的原始代码
LDAv.visualize_plotly_heatmap(dtM)
# Out:
# array([[1.85412103e-01, 4.36080976e-01, 3.04205314e-01, 3.75418077e-04,
#         3.76264796e-04, 7.31759416e-02, 3.73982722e-04],
#        [3.98766395e-01, 1.42820728e-01, 4.93459117e-02, 1.81471647e-01,
#         2.26854170e-01, 3.71042395e-04, 3.70105787e-04],
#        [2.24133002e-01, 4.21322143e-01, 2.47496556e-01, 6.81557758e-02,
#         3.74532844e-02, 7.21343875e-04, 7.17894925e-04],
#        [3.14414620e-04, 3.14582958e-04, 3.14794118e-04, 3.14485681e-04,
#         3.14405788e-04, 9.98113343e-01, 3.13973986e-04],
#        [4.00991463e-01, 6.72922165e-04, 6.73589904e-04, 6.72589110e-04,
#         5.95646915e-01, 6.71812127e-04, 6.70708986e-04],
#        [7.15436226e-04, 7.14903731e-04, 7.15415575e-04, 7.15334445e-04,
#         9.95709499e-01, 7.15120191e-04, 7.14290444e-04],
#        [3.10028834e-01, 9.55230333e-04, 9.56195761e-04, 6.85200278e-01,
#         9.53285989e-04, 9.53776538e-04, 9.52399452e-04],
# ...

# %%
# 流水化?

# %%
# 批量化?

# %% [markdown]
# ### 实践问题3
# * 完成 试一个 流水化? 批量化?

# %% [markdown]
# ### 柱状图

# %% [markdown]
# ### 实践答案4
# * 完成 试一个 流水化? 批量化?
