# %% [markdown]
# # pyLDA交互可视化
# * [`pyLDAvis`](https://github.com/bmabey/pyLDAvis)
# * 有三种降维可视化方法
#     * PCOA
#     * TSNE
#     * MMDS
#
# ## pyLDA输入/输出
#
# * 输入模型
# * 输出可视化，可用於
#     * N之决定
#     * 字词检查
#
# ## 学习目标
#
# * 观察输入输出
# * 注意数据流

# %%
# path ：
fn = { "LDA_pickle_n": "pkl/LDA_{n}.pickle",
       "LDA_visualize_pyLDA_kind_n": "html_out/pyLDAvis_{kind}_{n}.html",
      }

# %% [markdown]
# ## 模块化
# * LDA_visualize_interactive.py
#
#
# ```
# """
# 本代码会将model数据与excel打包生成dict数据类型
# n_min,n_max导入（决定几个主题）主题模型的文件，根据已生成的LD模型pkl档和excel档具体情况而定
# 例如:pkl档和excel档有[df_LDA_4,df_LDA_5,df_LDA_6]则n_min=4，n_max=7（range()决定）
# """
#
# ```

# %%
import LDA_visualize as LDAv

# %%
# single

LDAv.single_pyLDAvis(4, fn["LDA_pickle_n"], fn["LDA_visualize_pyLDA_kind_n"], 'TSNE')
# Out:
# ({'doc_lengths': [1839,
#    1453,
#    506,
#    635,
#    622,
#    701,
#    724,
#    690,
#    508,
#    1021,
#    1019,
#    775,
#    1277,
#    996,
#    339,
#    1178,
#    808,
#    564,
#    1612,
#    624,
#    348,
#    656,
#    601,
#    970,
#    1096,
#    640,
#    681,
#    484,
#    664,
#    1592,
#    1586,
#    1524,
#    1052,
#    860,
#    244,
#    396,
#    731,
#    649,
#    1764,
#    754,
#    1086,
#    991,
#    1385,
#    298,
#    782,
#    671,
#    1296,
#    738,
#    625],
#   'term_frequency': [47,
#    13,
#    45,
#    6,
#    7,
#    4,
#    15,
#    4,
#    4,
#    4,
#    4,
#    5,
#    35,
#    5,
#    5,
#    4,
#    25,
#    5,
#    7,
#    19,
#    6,
#    8,
#    5,
#    7,
#    36,
#    6,
#    5,
#    17,
#    13,
#    4,
#    6,
#    5,
#    30,
#    46,
#    5,
#    15,
#    7,
#    5,
#    5,
#    5,
#    5,
#    17,
#    24,
#    57,
#    9,
#    9,
#    22,
#    21,
#    4,
#    27,
#    53,
#    5,
#    6,
#    4,
# ...

# %%
# batch

for m in ['PCOA','TSNE','MMDS']:
    LDAv.batch_pyLDAvis(4, 12, fn["LDA_pickle_n"], fn["LDA_visualize_pyLDA_kind_n"], m)
# Out:
# exporting html_out/pyLDAvis_PCOA_4.html
# exporting html_out/pyLDAvis_PCOA_5.html
# exporting html_out/pyLDAvis_PCOA_6.html
# exporting html_out/pyLDAvis_PCOA_7.html
# exporting html_out/pyLDAvis_PCOA_8.html
# exporting html_out/pyLDAvis_PCOA_9.html
# exporting html_out/pyLDAvis_PCOA_10.html
# exporting html_out/pyLDAvis_PCOA_11.html
# exporting html_out/pyLDAvis_PCOA_12.html
# exporting html_out/pyLDAvis_TSNE_4.html
# exporting html_out/pyLDAvis_TSNE_5.html
# exporting html_out/pyLDAvis_TSNE_6.html
# exporting html_out/pyLDAvis_TSNE_7.html
# exporting html_out/pyLDAvis_TSNE_8.html
# exporting html_out/pyLDAvis_TSNE_9.html
# exporting html_out/pyLDAvis_TSNE_10.html
# exporting html_out/pyLDAvis_TSNE_11.html
# exporting html_out/pyLDAvis_TSNE_12.html
# exporting html_out/pyLDAvis_MMDS_4.html
# exporting html_out/pyLDAvis_MMDS_5.html
# exporting html_out/pyLDAvis_MMDS_6.html
# exporting html_out/pyLDAvis_MMDS_7.html
# exporting html_out/pyLDAvis_MMDS_8.html
# ...
